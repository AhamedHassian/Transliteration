# %%
import pandas as pd
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate
from metaphone import doublemetaphone
from sklearn.cluster import AgglomerativeClustering
from Levenshtein import distance as levenshtein_distance
import numpy as np
import tensorflow

# %%
# Load the dataset
file_path = "male.csv"  # Replace with your file path
df = pd.read_csv(file_path)

# Ensure column is correctly named
if "names" not in df.columns:
    raise ValueError("The dataset must have a column named 'names'.")

# %%
# Step 1: Normalize the names (remove extra spaces and convert to lowercase)
df["Normalized_Names"] = df["names"].str.strip().str.lower()

# %%
# Step 2: Transliterate names to Tamil (if necessary)
# Comment this block if names are already in Tamil
df["Tamil_Names"] = df["Normalized_Names"].apply(
    lambda x: transliterate(x, sanscript.ITRANS, sanscript.TAMIL)
)

# %%
# Step 3: Generate phonetic keys using Double Metaphone
df["Phonetic_Keys"] = df["Normalized_Names"].apply(lambda x: doublemetaphone(x)[0])

# %%
# Step 4: Compute pairwise Levenshtein distances between phonetic keys
phonetic_keys = df["Phonetic_Keys"].tolist()
num_names = len(phonetic_keys)
dist_matrix = np.zeros((num_names, num_names))

for i in range(num_names):
    for j in range(num_names):
        dist_matrix[i, j] = levenshtein_distance(phonetic_keys[i], phonetic_keys[j])

# %%
# Step 5: Perform clustering
clustering = AgglomerativeClustering(
    n_clusters=None, metric="precomputed", linkage="average", distance_threshold=2.0
)
labels = clustering.fit_predict(dist_matrix)

# %%
# Step 6: Group names into clusters and find a representative name
df["Cluster_Labels"] = labels

clusters = {}
for label, name in zip(labels, df["names"]):
    clusters.setdefault(label, []).append(name)

# Select a representative name for each cluster (shortest name as default)
representative_names = {label: min(cluster, key=len) for label, cluster in clusters.items()}

# Map each name to its representative name
df["Representative_Name"] = df["Cluster_Labels"].apply(lambda x: representative_names[x])

# %%
# Save the updated dataset to a new CSV file
output_file_path = "processed_male_names_dataset.csv"
df.to_csv(output_file_path, index=False, encoding="utf-8")
print(f"Processed dataset saved to {output_file_path}")

# Display clusters and mappings (optional)
print("\nClusters and Representative Names:")
for label, cluster in clusters.items():
    print(f"Cluster {label}: {cluster} -> Representative: {representative_names[label]}")
# Out:
# Processed dataset saved to processed_male_names_dataset.csv
#
# Clusters and Representative Names:
# Cluster 46: ['Aaron', 'Adrian', 'Adrien', 'Aharon', 'Arne', 'Arnie', 'Aron', 'Arron', 'Barn', 'Barney', 'Barnie', 'Barny', 'Baron', 'Barron', 'Bernie', 'Bjorn', 'Bjorne', 'Brian', 'Bruno', 'Bryan', 'Bryn', 'Bryon', 'Byron', 'Darby', 'Daren', 'Darian', 'Darien', 'Darin', 'Dario', 'Darrel', 'Darrell', 'Darren', 'Darrin', 'Darryl', 'Darth', 'Darwin', 'Daryl', 'Daryle', 'Derby', 'Derrin', 'Derrol', 'Derron', 'Deryl', 'Dorian', 'Dory', 'Drew', 'Dru', 'Erin', 'Ernie', 'Erny', 'Erwin', 'Eugen', 'Eugene', 'Hadrian', 'Irwin', 'Lauren', 'Loren', 'Lorne', 'Marion', 'Marwin', 'Merwin', 'Myron', 'Oberon', 'Oran', 'Oren', 'Orin', 'Orion', 'Orren', 'Orrin', 'Sherwin', 'Stearn', 'Stearne', 'Stern', 'Sterne', 'Terrel', 'Terrell', 'Terri', 'Terrill', 'Terry', 'Tharen', 'Thorn', 'Thornie', 'Thorny', 'Tirrell', 'Tore', 'Torey', 'Torin', 'Torr', 'Torre', 'Torrey', 'Torrin', 'Torry', 'Tray', 'Tre', 'Trey', 'Trip', 'Troy', 'Tyrone', 'Warren'] -> Representative: Dru
# Cluster 11: ['Abbey', 'Abbie', 'Abby', 'Abe', 'Ash', 'Ashby', 'Aub', 'Aube', 'Bay', 'Beau', 'Bishop', 'Bo', 'Bob', 'Bobbie', 'Bobby', 'Bubba', 'Che', 'Chip', 'Cob', 'Cobb', 'Cobbie', 'Cobby', 'Cy', 'Fabio', 'Gabe', 'Gay', 'Geo', 'Gibb', 'Guy', 'Hew', 'Hewe', 'Hewie', 'Howie', 'Huey', 'Hy', 'Jae', 'Jay', 'Jeb', 'Jo', 'Joab', 'Joao', 'Job', 'Joe', 'Joey', 'Kip', 'Lay', 'Lee', 'Leigh', 'Leo', 'Lew', 'Lou', 'Louie', 'Luigi', 'Moe', 'Obie', 'Pepe', 'Phip', 'Pip', 'Pooh', 'Rab', 'Rabbi', 'Rabi', 'Ray', 'Reube', 'Rey', 'Rob', 'Robb', 'Robbie', 'Roy', 'Rube', 'Ruby', 'Saw', 'Say', 'See', 'Shaw', 'Shay', 'Shea', 'Shep', 'Si', 'Tab', 'Tabb', 'Tabbie', 'Tabby', 'Tobe', 'Tobiah', 'Tobie', 'Toby', 'Vibhu', 'Wash', 'Way', 'Web', 'Webb', 'Wye', 'Zeb', 'Zippy'] -> Representative: Bo
# Cluster 26: ['Abbot', 'Abbott', 'Abdel', 'Abdul', 'Abdullah', 'Abel', 'Abner', 'Apollo', 'Eben', 'Ichabod', 'Obadiah', 'Orbadiah'] -> Representative: Abel
# Cluster 191: ['Abdulkarim'] -> Representative: Abdulkarim
# Cluster 42: ['Abelard', 'Albert', 'Alberto', 'Albrecht', 'Alford', 'Alfred', 'Alfredo', 'Aubert', 'Eberhard', 'Egbert', 'Elbert', 'Ethelbert', 'Ethelred', 'Oliver', 'Osbert', 'Ulberto', 'Umberto', 'Wilbert', 'Wilburt', 'Wilfred', 'Wilfrid', 'Willard', 'Wolfram'] -> Representative: Albert
# Cluster 112: ['Abraham', 'Abram', 'Aram', 'Byram', 'Ibrahim'] -> Representative: Aram
# Cluster 44: ['Ace', 'Amos', 'Aziz', 'Chas', 'Chase', 'Emmy', 'Esau', 'Ez', 'Hasty', 'Hezekiah', 'Isa', 'Isaac', 'Isaak', 'Isaiah', 'Izaak', 'Izak', 'Izzy', 'Les', 'Lewis', 'Louis', 'Luce', 'Lucio', 'Luis', 'Mace', 'Moise', 'Mose', 'Moss', 'Ossie', 'Ozzie', 'Ozzy', 'Roscoe', 'Wes', 'Zeus'] -> Representative: Ez
# Cluster 41: ['Adair', 'Adam', 'Addie', 'Aditya', 'Adlai', 'Ahmad', 'Ahmed', 'Ahmet', 'Benito', 'Bennet', 'Bennett', 'Boyd', 'Bud', 'Buddy', 'Cat', 'Cody', 'Daffy', 'Dale', 'Dallas', 'Dave', 'Davey', 'David', 'Davidde', 'Davide', 'Davie', 'Davis', 'Davoud', 'Davy', 'Del', 'Dell', 'Dewey', 'Dewitt', 'Dov', 'Doyle', 'Dudley', 'Duffie', 'Duffy', 'Dwight', 'Ed', 'Eddie', 'Eddy', 'Edie', 'Edwin', 'Emmet', 'Emmett', 'Emmit', 'Emmott', 'Etienne', 'Fidel', 'Guido', 'Hamid', 'Hammad', 'Hamnet', 'Haywood', 'Hewet', 'Hewett', 'Hewitt', 'Heywood', 'Hoyt', 'Hunt', 'Hyatt', 'Jed', 'Jodi', 'Jodie', 'Jody', 'Jud', 'Judah', 'Judd', 'Jude', 'Judy', 'Kit', 'Lloyd', 'Maddie', 'Maddy', 'Mahmoud', 'Mahmud', 'Mateo', 'Matt', 'Matteo', 'Mattie', 'Matty', 'Mead', 'Meade', 'Nat', 'Natale', 'Nate', 'Ned', 'Neddie', 'Neddy', 'Odell', 'Odie', 'Odin', 'Otes', 'Otis', 'Otto', 'Paddie', 'Paddy', 'Pat', 'Pate', 'Pattie', 'Patty', 'Pete', 'Petey', 'Piet', 'Shumeet', 'Sid', 'Smitty', 'Stew', 'Stu', 'Syd', 'Tad', 'Tadd', 'Taddeo', 'Tait', 'Taite', 'Tallie', 'Tally', 'Tate', 'Ted', 'Tedd', 'Teddie', 'Teddy', 'Tedie', 'Tiebout', 'Tito', 'Tobit', 'Tod', 'Todd', 'Toddie', 'Toddy', 'Tull', 'Tulley', 'Tully', 'Ty', 'Tye', 'Udale', 'Udall', 'Udell', 'Vite', 'Vito', 'Wade', 'Wait', 'Waite', 'Waiter', 'Wat', 'Weidar', 'Weider', 'Whit', 'Whitby', 'Whitney', 'Wiatt', 'Wit', 'Wittie', 'Witty', 'Wood', 'Woodie', 'Woodrow', 'Woody', 'Wyatan', 'Wyatt', 'Zed'] -> Representative: Ed
# Cluster 77: ['Adams', 'Adnan', 'Odysseus', 'Whitman', 'Woodman'] -> Representative: Adams
# Cluster 18: ['Adger', 'Amery', 'Amory', 'Ari', 'Arie', 'Aubrey', 'Avery', 'Caesar', 'Cesar', 'Connor', 'Conroy', 'Cyril', 'Cyrill', 'Cyrille', 'Emery', 'Emmery', 'Emory', 'Er', 'Ezra', 'Gomer', 'Gunner', 'Guthrey', 'Guthrie', 'Guthry', 'Henri', 'Henrie', 'Henry', 'Homer', 'Ira', 'Ivor', 'Jethro', 'Lamar', 'Lemar', 'Lothar', 'Luther', 'Major', 'Mario', 'Maurie', 'Maury', 'Mayer', 'Mayor', 'Meier', 'Meir', 'Merry', 'Meyer', 'Monroe', 'Moore', 'Morrie', 'Morry', 'Munroe', 'Murray', 'Nero', 'Omar', 'Ragnar', 'Rainer', 'Rayner', 'Raynor', 'Sawyer', 'Sawyere', 'Sayer', 'Sayre', 'Seymour', 'Siffre', 'Thacher', 'Thatcher', 'Thor', 'Uri', 'Uriah', 'Ware', 'Weber', 'Xever', 'Yuri', 'Zacharia', 'Zachariah', 'Zacharie', 'Zachary', 'Zacherie', 'Zachery', 'Zackariah', 'Zary', 'Zechariah', 'Zorro'] -> Representative: Er
# Cluster 108: ['Adolf', 'Adolfo', 'Adolph', 'Adolphe', 'Adolpho', 'Adolphus', 'Radcliffe', 'Rodolfo', 'Rodolph', 'Rodolphe', 'Rudolf', 'Rudolfo', 'Rudolph', 'Rutledge'] -> Representative: Adolf
# Cluster 93: ['Adrick', 'Anurag', 'Enrico', 'Enrique', 'Heinrich', 'Henrik', 'Henrique', 'Herrick'] -> Representative: Adrick
# Cluster 135: ['Agamemnon'] -> Representative: Agamemnon
# Cluster 80: ['Aguinaldo', 'Wakefield', 'Winfield', 'Winifield'] -> Representative: Winfield
# Cluster 151: ['Aguste', 'Agustin', 'August', 'Augustin', 'Augustine', 'Augusto', 'Augustus', 'West', 'Winston'] -> Representative: West
# Cluster 53: ['Ajai', 'Ajay', 'Augie', 'Dougie', 'Hodge', 'Page', 'Paige', 'Raj', 'Rajeev', 'Regen', 'Rodge', 'Rodger', 'Vijay'] -> Representative: Raj
# Cluster 45: ['Al', 'Alaa', 'Alain', 'Alan', 'Aldo', 'Alec', 'Aleck', 'Alf', 'Alfie', 'Ali', 'Alic', 'Allah', 'Allan', 'Allen', 'Alley', 'Allie', 'Allin', 'Allyn', 'Alonso', 'Alonzo', 'Aloysius', 'Alwin', 'Ashish', 'Ashley', 'Ehud', 'Eli', 'Elias', 'Elihu', 'Elijah', 'Eliot', 'Eliott', 'Elisha', 'Elliot', 'Elliott', 'Ellis', 'Ellwood', 'Elric', 'Elvis', 'Elwin', 'Elwood', 'Elwyn', 'Ely', 'Enoch', 'Euclid', 'Evelyn', 'Olaf', 'Olag', 'Ole', 'Oleg', 'Olin', 'Olivier', 'Olle', 'Ollie', 'Oswell', 'Othello', 'Uli', 'Ulick', 'Ulises', 'Ulric', 'Ulrick', 'Ulysses', 'Wald', 'Waldo', 'Waleed', 'Wallace', 'Wallache', 'Wallas', 'Wallie', 'Wallis', 'Wally', 'Walsh', 'Walt', 'Waylan', 'Wayland', 'Waylen', 'Waylin', 'Waylon', 'Welch', 'Wells', 'Welsh', 'Wesley', 'Weslie', 'Weylin', 'Wilek', 'Wiley', 'Will', 'Willem', 'Willey', 'Willi', 'William', 'Willie', 'Willis', 'Willmott', 'Willy', 'Wilt', 'Witold', 'Wolf', 'Wolfie', 'Wolfy', 'Wylie', 'Yale', 'Yehudi', 'Yule', 'Yves'] -> Representative: Al
# Cluster 20: ['Alasdair', 'Alastair', 'Alister', 'Chester', 'Isador', 'Isadore', 'Isidore', 'Lester', 'Nester', 'Nestor', 'Rochester', 'Schroeder', 'Webster'] -> Representative: Isador
# Cluster 123: ['Albatros'] -> Representative: Albatros
# Cluster 95: ['Alden', 'Aldwin', 'Alston', 'Alton', 'Ashton', 'Austen', 'Austin', 'Chelton', 'Clayton', 'Easton', 'Elden', 'Eldon', 'Elton', 'Fulton', 'Hilton', 'Lawton', 'Layton', 'Leighton', 'Milton', 'Shelden', 'Sheldon', 'Shelton', 'Upton', 'Walden', 'Waldon', 'Walton', 'Weston', 'Wilden', 'Wildon', 'Willdon', 'Wilton'] -> Representative: Alden
# Cluster 5: ['Aldis', 'Aldus', 'Amadeus', 'Claudius', 'Cletus', 'Cortese', 'Curtice', 'Curtis', 'Eustace', 'Fritz', 'Horatius', 'Kostas', 'Kurtis', 'Maurits', 'Mauritz', 'Obadias', 'Quintus'] -> Representative: Aldis
# Cluster 75: ['Aldric', 'Aldrich', 'Ulrich'] -> Representative: Aldric
# Cluster 100: ['Alejandro', 'Alessandro'] -> Representative: Alejandro
# Cluster 134: ['Aleks', 'Alex', 'Alexei', 'Alexis', 'Alix', 'Angus', 'Felix', 'Lex', 'Lucas', 'Lukas'] -> Representative: Lex
# Cluster 173: ['Aleksandrs', 'Alexander'] -> Representative: Alexander
# Cluster 104: ['Alfonse', 'Alfonso', 'Alfonzo', 'Alphonse', 'Alphonso', 'Silvanus'] -> Representative: Alfonse
# Cluster 163: ['Algernon'] -> Representative: Algernon
# Cluster 13: ['Alvin', 'Calvin', 'Clifton', 'Elvin', 'Evan', 'Garvin', 'Griffin', 'Griffith', 'Ivan', 'Kalvin', 'Kelvin', 'Levin', 'Levon', 'Marven', 'Marvin', 'Melvin', 'Melvyn', 'Mervin', 'Reuven', 'Silvain', 'Silvan', 'Silvano', 'Stefan', 'Stefano', 'Steffen', 'Stephan', 'Stephen', 'Steven', 'Sullivan', 'Sylvan'] -> Representative: Evan
# Cluster 59: ['Ambros', 'Ambrose', 'Ambrosi', 'Ambrosio', 'Ambrosius'] -> Representative: Ambros
# Cluster 187: ['Anatol', 'Anatole', 'Anatollo', 'Anatoly', 'Andie', 'Andonis', 'Andre', 'Andrea', 'Andrew', 'Andrey', 'Andri', 'Andy', 'Anson', 'Anthony', 'Antin', 'Antoine', 'Anton', 'Antone', 'Antoni', 'Antonin', 'Antonino', 'Antonio', 'Antonius', 'Antony', 'Ender', 'Wendall', 'Wendel', 'Wendell', 'Windham', 'Winton', 'Wyndham', 'Wynton', 'Yanaton'] -> Representative: Andy
# Cluster 67: ['Anders', 'Andreas', 'Andrej', 'Andres', 'Andros', 'Andrus', 'Andrzej', 'Henderson', 'Sanders', 'Sanderson', 'Saunders', 'Saunderson'] -> Representative: Anders
# Cluster 57: ['Angel', 'Angelico', 'Angelo', 'Nigel'] -> Representative: Angel
# Cluster 85: ['Angie', 'Hank', 'Inigo', 'Wang', 'Waring', 'Woochang', 'Yance', 'Yancey', 'Yancy', 'Yank', 'Yankee'] -> Representative: Hank
# Cluster 55: ['Ansel', 'Ansell', 'Anselm', 'Axel', 'Edsel', 'Winslow', 'Yigal'] -> Representative: Axel
# Cluster 133: ['Apostolos'] -> Representative: Apostolos
# Cluster 223: ['Archibald', 'Archibold'] -> Representative: Archibald
# Cluster 3: ['Archie', 'Archy', 'Butch', 'Erich', 'Hamish', 'Hersch', 'Hersh', 'Hirsch', 'Manish', 'Marsh', 'Mischa', 'Mitch', 'Moishe', 'Moshe', 'Noach', 'Ramesh', 'Rich', 'Richie', 'Richy', 'Ritch', 'Ritchie', 'Sancho', 'Sascha', 'Sasha', 'Sauncho', 'Thatch', 'Xenos'] -> Representative: Rich
# Cluster 81: ['Archon', 'Arvin', 'Arvind', 'Ervin', 'Irvin', 'Irvine', 'Irving', 'Orson', 'Urbain', 'Urban', 'Urbano', 'Urbanus', 'Urson'] -> Representative: Arvin
# Cluster 27: ['Arel', 'Ariel', 'Arlo', 'Burl', 'Cecil', 'Charley', 'Charlie', 'Connolly', 'Earl', 'Earle', 'Emil', 'Emile', 'Emilio', 'Erl', 'Errol', 'Fazeel', 'Harley', 'Harwell', 'Hazel', 'Hillel', 'Hurley', 'Kalil', 'Lemuel', 'Linoel', 'Lionel', 'Lionello', 'Lowell', 'Lyle', 'Manuel', 'Marilu', 'Marlo', 'Marlow', 'Marlowe', 'Mel', 'Mendel', 'Merell', 'Merill', 'Merle', 'Merrel', 'Merril', 'Merrill', 'Meryl', 'Michael', 'Michail', 'Michal', 'Michale', 'Micheal', 'Micheil', 'Michel', 'Michele', 'Miguel', 'Mikael', 'Mikel', 'Mikhail', 'Milo', 'Mitchael', 'Mitchel', 'Mitchell', 'Morlee', 'Morley', 'Morly', 'Mylo', 'Neal', 'Neale', 'Neall', 'Nealy', 'Neel', 'Neil', 'Niall', 'Niccolo', 'Nichole', 'Nikolai', 'Noel', 'Oral', 'Orville', 'Quiggly', 'Quigly', 'Raleigh', 'Raoul', 'Raul', 'Rawley', 'Reilly', 'Riley', 'Rollo', 'Royal', 'Russel', 'Russell', 'Sal', 'Samuel', 'Samuele', 'Saul', 'Shell', 'Shelley', 'Sibyl', 'Sly', 'Sol', 'Sollie', 'Solly', 'Sully', 'Uriel', 'Vasili', 'Vasily', 'Vassili', 'Vassily', 'Yardley', 'Zollie', 'Zolly'] -> Representative: Erl
# Cluster 179: ['Aristotle'] -> Representative: Aristotle
# Cluster 49: ['Armand', 'Armando', 'Armond', 'Fremont', 'Norman', 'Normand', 'Raimund', 'Raymond', 'Raymund', 'Raymundo', 'Redmond', 'Richmond'] -> Representative: Armand
# Cluster 127: ['Armstrong'] -> Representative: Armstrong
# Cluster 167: ['Arnold', 'Arnoldo', 'Reginald', 'Reginauld', 'Reinhold', 'Renaldo', 'Renault', 'Reynold', 'Reynolds', 'Rinaldo', 'Ronald'] -> Representative: Arnold
# Cluster 23: ['Art', 'Artie', 'Baird', 'Bard', 'Barde', 'Barret', 'Barrett', 'Bart', 'Bartie', 'Barty', 'Bayard', 'Beaufort', 'Bert', 'Bertie', 'Bharat', 'Bogart', 'Brad', 'Brady', 'Bret', 'Brett', 'Britt', 'Broddie', 'Broddy', 'Brodie', 'Brody', 'Burt', 'Chariot', 'Claude', 'Claudio', 'Clint', 'Clyde', 'Conrad', 'Costa', 'Curt', 'Edgardo', 'Edouard', 'Eduard', 'Eduardo', 'Edward', 'Everett', 'Ewart', 'Ferd', 'Ferdie', 'Ferdy', 'Ford', 'Fred', 'Freddie', 'Freddy', 'Garret', 'Garrett', 'Garrot', 'Garrott', 'Garwood', 'Gerrit', 'Giraud', 'Gordie', 'Grady', 'Grant', 'Hart', 'Hayward', 'Horatio', 'Howard', 'Jared', 'Jarrett', 'Jordy', 'Kennedy', 'Kent', 'Kincaid', 'Konrad', 'Kurt', 'Laird', 'Lars', 'Marietta', 'Mart', 'Martie', 'Marty', 'Mort', 'Mortie', 'Morty', 'Norwood', 'Quent', 'Quint', 'Rad', 'Red', 'Reed', 'Reid', 'Rhett', 'Rod', 'Rodd', 'Roddie', 'Roddy', 'Rudd', 'Ruddie', 'Ruddy', 'Rudie', 'Rudy', 'Sherwood', 'Shorty', 'Shurwood', 'Siward', 'Wainwright', 'Ward', 'Warde', 'Wright', 'Yard', 'Zared'] -> Representative: Art
# Cluster 92: ['Arther', 'Arthur', 'Artur', 'Arturo', 'Warner', 'Werner'] -> Representative: Artur
# Cluster 14: ['Arvie', 'Arvy', 'Ave', 'Avi', 'Beowulf', 'Biff', 'Ev', 'Harv', 'Harvey', 'Harvie', 'Herve', 'Hervey', 'Leif', 'Lev', 'Levi', 'Levy', 'Marv', 'Marve', 'Merv', 'Murphy', 'Puff', 'Rafe', 'Ralf', 'Ralph', 'Ravi', 'Rolf', 'Rolfe', 'Rolph', 'Rufe', 'Silvio', 'Trev', 'Yaakov', 'Yacov'] -> Representative: Ev
# Cluster 189: ['Averell', 'Averil', 'Averill', 'Avraham', 'Avram', 'Avrom', 'Efram', 'Ephraim', 'Ephram', 'Ephrayim', 'Ephrem', 'Gavriel', 'Waverley', 'Waverly'] -> Representative: Avram
# Cluster 97: ['Aylmer', 'Delmar', 'Elmer', 'Elmore', 'Elnar', 'Elroy', 'Filmore', 'Palmer', 'Walker', 'Walter', 'Walther', 'Wheeler', 'Wilber', 'Wilbur', 'Wilmar', 'Wilmer'] -> Representative: Elmer
# Cluster 21: ['Bailey', 'Bailie', 'Baillie', 'Baily', 'Barr', 'Barri', 'Barrie', 'Barry', 'Barth', 'Barthel', 'Bary', 'Basil', 'Beale', 'Bealle', 'Bear', 'Bela', 'Bill', 'Billie', 'Billy', 'Blaine', 'Blake', 'Blayne', 'Boyce', 'Brewer', 'Pablo', 'Pace', 'Pail', 'Paolo', 'Parry', 'Partha', 'Paul', 'Paulo', 'Pepillo', 'Pepito', 'Perry', 'Pierre', 'Plato', 'Poul', 'Powell', 'Rory'] -> Representative: Barr
# Cluster 43: ['Baldwin', 'Bogdan', 'Buster', 'Padraig', 'Paten', 'Patin', 'Paton', 'Patric', 'Patrice', 'Patricio', 'Patrick', 'Patrik', 'Pedro', 'Peter', 'Petr', 'Peyter', 'Peyton', 'Pieter', 'Pietro', 'Piotr', 'Porter', 'Putnam', 'Pyotr'] -> Representative: Petr
# Cluster 129: ['Bancroft'] -> Representative: Bancroft
# Cluster 70: ['Barbabas', 'Barnabas', 'Barnabe', 'Barnaby', 'Barnebas', 'Burnaby'] -> Representative: Barnabe
# Cluster 33: ['Barclay', 'Beck', 'Berk', 'Berke', 'Berkeley', 'Berkie', 'Berkley', 'Bing', 'Binky', 'Brock', 'Brook', 'Brooke', 'Buck', 'Bucky', 'Burke', 'Chadwick', 'Chuck', 'Darrick', 'Derek', 'Derick', 'Derk', 'Derrek', 'Derrick', 'Dick', 'Dickey', 'Dickie', 'Diego', 'Dirk', 'Doug', 'Douggie', 'Drake', 'Dryke', 'Dugan', 'Duke', 'Erek', 'Eric', 'Erick', 'Erik', 'Hugo', 'Iago', 'Iggie', 'Iggy', 'Ike', 'Ikey', 'Locke', 'Ludwig', 'Luke', 'Mac', 'Mack', 'Marc', 'Marco', 'Mark', 'Marko', 'Merrick', 'Mic', 'Micah', 'Mick', 'Mickey', 'Mickie', 'Micky', 'Mika', 'Mike', 'Mikey', 'Myke', 'Nick', 'Nickey', 'Nickie', 'Nicky', 'Nico', 'Niki', 'Nikki', 'Paco', 'Park', 'Parke', 'Parker', 'Piggy', 'Reg', 'Reggie', 'Reggy', 'Ric', 'Rick', 'Rickey', 'Ricki', 'Rickie', 'Ricky', 'Rik', 'Rikki', 'Roarke', 'Rock', 'Rocky', 'Rog', 'Rourke', 'Sig', 'Sky', 'Skye', 'Stig', 'Tuck', 'Tucker', 'Tuckie', 'Tucky', 'Ugo', 'Vic', 'Vick', 'Wake', 'Zach', 'Zack', 'Zak', 'Zedekiah', 'Zeke', 'Zerk'] -> Representative: Ike
# Cluster 39: ['Barnard', 'Bearnard', 'Beauregard', 'Bengt', 'Bernard', 'Bernardo', 'Bernhard', 'Harcourt', 'Norbert', 'Penrod', 'Raynard', 'Reinhard', 'Renard', 'Reynard', 'Ricard', 'Ricardo', 'Riccardo', 'Richard', 'Richardo', 'Rickard', 'Robbert', 'Robert', 'Roberto', 'Rupert', 'Ruperto'] -> Representative: Bengt
# Cluster 36: ['Barnett', 'Bernd', 'Brandon', 'Brandy', 'Brant', 'Brendan', 'Brent', 'Bryant', 'Durand', 'Durant', 'Durante', 'Laurent', 'Praneetf', 'Prent', 'Prentice', 'Prentiss', 'Rand', 'Randi', 'Randie', 'Randy', 'Renado', 'Renato', 'Renaud', 'Ronen', 'Sherwynd', 'Tarrant', 'Thorndike', 'Thornton', 'Trent', 'Trenton'] -> Representative: Rand
# Cluster 9: ['Barris', 'Boris', 'Brice', 'Briggs', 'Brooks', 'Bruce', 'Bryce', 'Burgess', 'Cyrus', 'Darcy', 'Darius', 'Fergus', 'Fox', 'Frazier', 'Harris', 'Harrison', 'Horace', 'Horacio', 'Horst', 'Lucius', 'Marcio', 'Marcos', 'Marcus', 'Marius', 'Markos', 'Markus', 'Mathias', 'Matias', 'Matthaeus', 'Mattheus', 'Matthias', 'Matthus', 'Mattias', 'Maurice', 'Mauricio', 'Maurise', 'Max', 'Maxie', 'Miles', 'Moises', 'Morris', 'Morse', 'Moses', 'Mugsy', 'Myles', 'Norris', 'Orazio', 'Pearce', 'Peirce', 'Percy', 'Pierce', 'Price', 'Prince', 'Pryce', 'Reece', 'Rees', 'Reese', 'Reggis', 'Rex', 'Reza', 'Rice', 'Roice', 'Ross', 'Royce', 'Russ', 'Sax', 'Saxe', 'Sayers', 'Sayres', 'Trace', 'Tracey', 'Tracie', 'Tracy', 'Tyrus'] -> Representative: Fox
# Cluster 28: ['Bartel', 'Bartlet', 'Bartlett', 'Bartolemo', 'Bartolomei', 'Bartolomeo', 'Bentley', 'Bertram', 'Bradley', 'Bradly', 'Parnell', 'Parrnell', 'Patel', 'Purcell'] -> Representative: Patel
# Cluster 35: ['Bartholemy', 'Bartholomeo', 'Bartholomeus', 'Bartholomew', 'Batholomew'] -> Representative: Bartholemy
# Cluster 24: ['Barton', 'Braden', 'Burton', 'Carter', 'Courtney', 'Creighton', 'Gardener', 'Gardiner', 'Gardner', 'Giordano', 'Gordan', 'Gordon', 'Jordan', 'Jordon', 'Martainn', 'Marten', 'Martin', 'Martino', 'Martyn', 'Morten', 'Morton', 'Norton', 'Orton', 'Rodney', 'Sheridan', 'Warden', 'Worden'] -> Representative: Orton
# Cluster 117: ['Baxter', 'Dexter', 'Thaxter'] -> Representative: Baxter
# Cluster 0: ['Ben', 'Benji', 'Benjie', 'Benjy', 'Benn', 'Bennie', 'Benny', 'Chad', 'Chadd', 'Chaddie', 'Chaddy', 'Chaim', 'Chan', 'Chance', 'Chancey', 'Chane', 'Chaunce', 'Chauncey', 'Chen', 'Chet', 'Chev', 'Chevy', 'Dabney', 'Damian', 'Damien', 'Damon', 'Dan', 'Dana', 'Dane', 'Dani', 'Danie', 'Daniel', 'Dannie', 'Danny', 'Dante', 'Davin', 'Davon', 'Dawson', 'Dean', 'Deane', 'Denis', 'Dennie', 'Dennis', 'Denny', 'Devin', 'Devon', 'Dino', 'Dion', 'Dionis', 'Don', 'Donal', 'Donn', 'Donnie', 'Donny', 'Duane', 'Dunc', 'Dwain', 'Dwaine', 'Dwane', 'Dwayne', 'Dyson', 'Ethan', 'Ewan', 'Finley', 'Finn', 'Fons', 'Fonsie', 'Fonz', 'Fonzie', 'Gene', 'Gian', 'Hassan', 'Husain', 'Husein', 'Hussein', 'Hyman', 'Iain', 'Ian', 'Jan', 'Jean', 'John', 'Johnnie', 'Johnny', 'Johny', 'Jon', 'Jonah', 'Jonny', 'Juan', 'Lane', 'Lanny', 'Len', 'Lennie', 'Lenny', 'Leon', 'Lin', 'Lion', 'Lon', 'Lonnie', 'Lonny', 'Lyn', 'Lynn', 'Maison', 'Manny', 'Mason', 'Muffin', 'Nathan', 'Nevins', 'Noah', 'Noe', 'Nunzio', 'Owen', 'Pen', 'Penn', 'Pennie', 'Penny', 'Phineas', 'Rene', 'Ron', 'Roni', 'Ronnie', 'Ronny', 'Ryan', 'Sean', 'Shadow', 'Shaine', 'Shanan', 'Shane', 'Shannan', 'Shannon', 'Shaughn', 'Shaun', 'Shawn', 'Shayne', 'Sheff', 'Sheffie', 'Sheffy', 'Shem', 'Shimon', 'Simeon', 'Simon', 'Simone', 'Son', 'Sonnie', 'Sonny', 'Sunny', 'Sven', 'Swen', 'Tan', 'Tann', 'Tanney', 'Tannie', 'Tanny', 'Thain', 'Thaine', 'Thane', 'Thayne', 'Tobin', 'Tonnie', 'Tony', 'Town', 'Towney', 'Townie', 'Towny', 'Tymon', 'Tynan', 'Tyson', 'Van', 'Vance', 'Venkat', 'Vin', 'Vince', 'Vinnie', 'Vinny', 'Vinod', 'Von', 'Wain', 'Waine', 'Wayne', 'Win', 'Winn', 'Winnie', 'Winny', 'Wyn', 'Wynn', 'Zane'] -> Representative: Ben
# Cluster 122: ['Benedict'] -> Representative: Benedict
# Cluster 202: ['Benjamen', 'Benjamin'] -> Representative: Benjamen
# Cluster 76: ['Benson', 'Bronson', 'Pierson', 'Prasun', 'Robinson'] -> Representative: Benson
# Cluster 136: ['Benton', 'Clinten', 'Clinton', 'Kenton', 'Lyndon', 'Newton', 'Quentin', 'Quinlan', 'Quintin', 'Quinton', 'Valentin', 'Valentine'] -> Representative: Benton
# Cluster 156: ['Berchtold'] -> Representative: Berchtold
# Cluster 225: ['Bertrand'] -> Representative: Bertrand
# Cluster 78: ['Blair', 'Blare', 'Butler', 'Clair', 'Claire', 'Clare', 'Clark', 'Clarke', 'Fowler', 'Guillermo', 'Larry', 'Laurie', 'Leroy', 'Lorrie', 'Tailor', 'Taylor', 'Tiler', 'Tyler'] -> Representative: Blair
# Cluster 114: ['Boniface', 'Pincas', 'Pinchas', 'Pincus'] -> Representative: Pincas
# Cluster 126: ['Bradford'] -> Representative: Bradford
# Cluster 82: ['Brewster', 'Prasad', 'Prescott'] -> Representative: Prasad
# Cluster 226: ['Brinkley'] -> Representative: Brinkley
# Cluster 84: ['Broderic', 'Broderick', 'Federico', 'Frederic', 'Frederich', 'Frederick', 'Frederico', 'Frederik', 'Fredric', 'Fredrick', 'Friedric', 'Friedrich', 'Friedrick', 'Fyodor', 'Roderic', 'Roderick', 'Roderigo', 'Rodrick', 'Rodrigo', 'Rodrique', 'Tedrick', 'Teodorico', 'Thedric', 'Thedrick', 'Theodoric'] -> Representative: Fyodor
# Cluster 10: ['Cain', 'Cal', 'Calhoun', 'Carey', 'Carl', 'Carleigh', 'Carlie', 'Carlo', 'Carlos', 'Carroll', 'Cary', 'Caryl', 'Case', 'Casey', 'Cass', 'Chris', 'Chrissy', 'Chrisy', 'Claus', 'Clay', 'Clem', 'Clemmie', 'Cliff', 'Clive', 'Cole', 'Colin', 'Collin', 'Conan', 'Connie', 'Conway', 'Corby', 'Corey', 'Corky', 'Corrie', 'Corwin', 'Cory', 'Cosmo', 'Craig', 'Cris', 'Gail', 'Gale', 'Galen', 'Garcia', 'Garey', 'Garp', 'Garry', 'Garth', 'Garv', 'Garvey', 'Garvy', 'Garwin', 'Gary', 'Gav', 'Gaven', 'Gavin', 'Gayle', 'Gere', 'Geri', 'Gerome', 'Gerri', 'Gerry', 'Gil', 'Giles', 'Gill', 'Gilles', 'Gino', 'Glen', 'Glenn', 'Glynn', 'Godwin', 'Goose', 'Grace', 'Graehme', 'Graeme', 'Graham', 'Graig', 'Greg', 'Gregg', 'Greggory', 'Gregor', 'Gregorio', 'Gregory', 'Griff', 'Grove', 'Guillaume', 'Gus', 'Herb', 'Herbie', 'Herby', 'Kalle', 'Kane', 'Kareem', 'Karel', 'Karim', 'Karl', 'Keefe', 'Keenan', 'Keene', 'Keil', 'Kellen', 'Kelley', 'Kelly', 'Kelsey', 'Kelwin', 'Ken', 'Kenn', 'Kenneth', 'Kenny', 'Kenyon', 'Kermie', 'Kerry', 'Kevan', 'Kevin', 'Kin', 'King', 'Kirby', 'Kirk', 'Klaus', 'Klee', 'Kory', 'Kraig', 'Kris', 'Kyle', 'Quill', 'Quillan', 'Quincey', 'Quincy', 'Quinn', 'Thorpe'] -> Representative: Cal
# Cluster 8: ['Caldwell', 'Hannibal', 'Hansel', 'Huntlee', 'Huntley', 'Kendal', 'Kendall', 'Noble', 'Randal', 'Randall', 'Randell', 'Randolf', 'Randolph'] -> Representative: Noble
# Cluster 128: ['Caleb', 'Farley', 'Felice', 'Felicio', 'Felipe', 'Filip', 'Filipe', 'Flem', 'Fletch', 'Floyd', 'Kaleb', 'Phil', 'Philip', 'Phillip', 'Phillipe', 'Phillipp', 'Shelby', 'Vachel', 'Vail', 'Val', 'Vale', 'Vlad', 'Welbie', 'Welby'] -> Representative: Val
# Cluster 40: ['Cam', 'Cammy', 'Dom', 'Hakeem', 'Hakim', 'Ham', 'Hasheem', 'Hashim', 'Hermy', 'Hiram', 'Hymie', 'Joachim', 'Kam', 'Kim', 'Kimmo', 'Lem', 'Lemmie', 'Lemmy', 'Liam', 'Nahum', 'Noam', 'Norm', 'Normie', 'Ram', 'Rem', 'Romeo', 'Sam', 'Sammie', 'Sammy', 'Sim', 'Tam', 'Tammie', 'Tammy', 'Thom', 'Tim', 'Timmie', 'Timmy', 'Tom', 'Tome', 'Tommie', 'Tommy'] -> Representative: Cam
# Cluster 146: ['Cameron'] -> Representative: Cameron
# Cluster 182: ['Carlin', 'Carlton', 'Garfield', 'Garold', 'Gerald', 'Geraldo', 'Gerold', 'Giraldo', 'Griswold', 'Harald', 'Harold', 'Harrold', 'Herold', 'Jerald', 'Jerold', 'Jerrold'] -> Representative: Carlin
# Cluster 69: ['Carlyle', 'Gamaliel'] -> Representative: Carlyle
# Cluster 4: ['Carmine', 'Corbin', 'Freeman', 'Freemon', 'Garcon', 'Germaine', 'Harlan', 'Harlin', 'Harman', 'Harmon', 'Herman', 'Hermann', 'Hermon', 'Herrmann', 'Jermain', 'Jermaine', 'Jermayne', 'Kermit', 'Marlin', 'Marlon', 'Merlin', 'Morgan', 'Quigman', 'Ramon', 'Reagan', 'Regan', 'Reuben', 'Robin', 'Rollin', 'Romain', 'Roman', 'Ruben', 'Rubin', 'Sherman', 'Tremain', 'Tremaine', 'Tremayne', 'Truman'] -> Representative: Ramon
# Cluster 58: ['Carson', 'Carsten', 'Christ', 'Christie', 'Christy', 'Forest', 'Forrest', 'Karsten', 'Preston', 'Rustie', 'Rustin', 'Rusty', 'Tarzan', 'Thorstein', 'Thorsten', 'Thurstan', 'Thurston', 'Tristan'] -> Representative: Rusty
# Cluster 83: ['Caspar', 'Casper', 'Cooper', 'Gabriel', 'Gabriele', 'Gabriell', 'Gabriello', 'Gaspar', 'Gasper', 'Goober', 'Jasper', 'Kaiser', 'Kaspar', 'Spiro'] -> Representative: Spiro
# Cluster 217: ['Chalmers'] -> Representative: Chalmers
# Cluster 145: ['Chanderjit'] -> Representative: Chanderjit
# Cluster 152: ['Chandler'] -> Representative: Chandler
# Cluster 176: ['Charles', 'Cyrillus', 'Sherlock', 'Sherlocke', 'Shurlock', 'Shurlocke'] -> Representative: Charles
# Cluster 196: ['Charleton', 'Charlton'] -> Representative: Charlton
# Cluster 172: ['Cheston', 'Dustin', 'Gaston', 'Justin', 'Sidnee', 'Sidney', 'Stan', 'Stanislaw', 'Stanleigh', 'Stanley', 'Stanly', 'Stanwood', 'Sting', 'Stinky', 'Sutton', 'Sydney'] -> Representative: Stan
# Cluster 48: ['Chevalier', 'Nev', 'Nevil', 'Nevile', 'Neville', 'Pavel', 'Rafael', 'Rahul', 'Raphael', 'Ravil', 'Ripley', 'Rufus'] -> Representative: Nev
# Cluster 162: ['Christian', 'Christiano', 'Gershom', 'Gershon', 'Gretchen', 'Krishna', 'Kristian'] -> Representative: Gershom
# Cluster 118: ['Christof', 'Christofer', 'Christoph', 'Christophe', 'Christopher', 'Christorpher', 'Cristopher', 'Kristopher'] -> Representative: Christof
# Cluster 88: ['Christos', 'Erasmus', 'Erastus', 'Kristos'] -> Representative: Erasmus
# Cluster 25: ['Churchill', 'Hartley', 'Hartwell', 'Hercule', 'Hercules', 'Herculie', 'Herschel', 'Hershel', 'Hiralal', 'Marchall', 'Marshal', 'Marshall', 'Rockwell'] -> Representative: Hartley
# Cluster 74: ['Clancy', 'Clarance', 'Clarence', 'Collins', 'Frans', 'Franz', 'Laurance', 'Laurence', 'Laurens', 'Lawerence', 'Lawrence', 'Lorenzo', 'Tarrance', 'Terence', 'Terencio', 'Terrance', 'Terrence', 'Torrance', 'Torrence', 'Travis'] -> Representative: Frans
# Cluster 66: ['Clayborn', 'Clayborne', 'Claybourne', 'Colbert', 'Delbert', 'Filbert', 'Flipper', 'Gilbert', 'Gilberto', 'Gilburt', 'Philbert', 'Talbert', 'Talbot'] -> Representative: Talbot
# Cluster 64: ['Cleland', 'Cleveland', 'Leland'] -> Representative: Leland
# Cluster 101: ['Clemens', 'Clement', 'Clemente', 'Coleman', 'Kalman', 'Lamont'] -> Representative: Kalman
# Cluster 37: ['Clifford', 'Crawford', 'Halvard', 'Hanford', 'Harvard', 'Manfred', 'Redford', 'Sanford', 'Siegfried', 'Sigfrid', 'Sigfried', 'Sivert', 'Staffard', 'Stafford', 'Staford', 'Winford', 'Winfred'] -> Representative: Sivert
# Cluster 200: ['Constantin', 'Constantine', 'Constantinos', 'Konstantin'] -> Representative: Constantin
# Cluster 140: ['Cornelius', 'Cornellis'] -> Representative: Cornelius
# Cluster 51: ['Dalton', 'Dillon', 'Duncan', 'Dylan', 'Tomkin', 'Tomlin'] -> Representative: Dylan
# Cluster 208: ['Davidson'] -> Representative: Davidson
# Cluster 30: ['Demetre', 'Demetri', 'Demetris', 'Demetrius', 'Dieter', 'Dimitri', 'Dimitrios', 'Dimitris', 'Dimitrou', 'Dimitry', 'Dmitri', 'Taber', 'Tabor', 'Tanner', 'Teador', 'Teodoor', 'Teodor', 'Teodoro', 'Tudor'] -> Representative: Taber
# Cluster 159: ['Demosthenis'] -> Representative: Demosthenis
# Cluster 16: ['Desmond', 'Desmund', 'Edmond', 'Edmund', 'Osmond', 'Osmund', 'Tedman', 'Tedmund'] -> Representative: Edmond
# Cluster 38: ['Dietrich', 'Godard', 'Godart', 'Goddard', 'Goddart', 'Roderich', 'Rudyard', 'Siddhartha', 'Steward', 'Stewart', 'Stuart'] -> Representative: Godard
# Cluster 235: ['Dionysus'] -> Representative: Dionysus
# Cluster 154: ['Domenic', 'Domenico', 'Dominic', 'Dominick', 'Dominique'] -> Representative: Domenic
# Cluster 87: ['Donald', 'Leopold', 'Thebault', 'Theobald', 'Thibaud', 'Thibaut', 'Tibold', 'Tiebold', 'Tybalt'] -> Representative: Donald
# Cluster 155: ['Donovan', 'Nealon', 'Neron', 'Nevin', 'Niven', 'Nolan'] -> Representative: Neron
# Cluster 22: ['Douglas', 'Douglass', 'Douglis', 'Jules', 'Julius', 'Knox', 'Nels', 'Nicholas', 'Nichols', 'Nickolas', 'Nicolas', 'Niels', 'Nikos', 'Niles', 'Nils', 'Silas'] -> Representative: Knox
# Cluster 178: ['Dunstan'] -> Representative: Dunstan
# Cluster 56: ['Durward', 'Erhard', 'Erhart', 'Everard', 'Gearard', 'Gerard', 'Gerhard', 'Gerhardt', 'Gerrard'] -> Representative: Erhard
# Cluster 71: ['Ebeneser', 'Ebenezer', 'Spencer', 'Spenser'] -> Representative: Spencer
# Cluster 6: ['Edgar', 'Igor', 'Oscar', 'Roger', 'Rudiger', 'Rutger', 'Rutter', 'Whitaker', 'Whittaker'] -> Representative: Igor
# Cluster 65: ['Ellsworth', 'Wadsworth'] -> Representative: Ellsworth
# Cluster 115: ['Emanuel', 'Emmanuel', 'Immanuel'] -> Representative: Emanuel
# Cluster 240: ['Emerson'] -> Representative: Emerson
# Cluster 61: ['Engelbart', 'Engelbert', 'Englebart', 'Englebert', 'Ingelbert', 'Inglebert'] -> Representative: Engelbart
# Cluster 234: ['Ernest', 'Ernesto', 'Ernst'] -> Representative: Ernst
# Cluster 12: ['Esme', 'Ezechiel', 'Ezekiel', 'Ishmael', 'Ismail', 'Israel', 'Westleigh', 'Westley'] -> Representative: Esme
# Cluster 116: ['Esteban', 'Istvan'] -> Representative: Istvan
# Cluster 170: ['Fabian', 'Flin', 'Flinn', 'Florian', 'Flynn', 'Fran', 'Francois', 'Frank', 'Frankie', 'Franky', 'French', 'Vaughan', 'Vaughn', 'Vern', 'Verne', 'Vernen', 'Verney', 'Vernon', 'Vernor'] -> Representative: Flin
# Cluster 228: ['Fairfax'] -> Representative: Fairfax
# Cluster 31: ['Ferdinand', 'Ferinand', 'Fernando', 'Harland', 'Hernando'] -> Representative: Harland
# Cluster 211: ['Ferguson'] -> Representative: Ferguson
# Cluster 1: ['Fitz', 'Patsy', 'Ramsay', 'Ramsey', 'Remus', 'Seamus', 'Shamus', 'Stacy', 'Taddeus', 'Tadeas', 'Tamas', 'Thad', 'Thaddeus', 'Thaddius', 'Thaddus', 'Thadeus', 'Theodor', 'Theodore', 'Thomas', 'Titos', 'Titus', 'Tobias', 'Tomas'] -> Representative: Fitz
# Cluster 143: ['Fitzgerald'] -> Representative: Fitzgerald
# Cluster 209: ['Fleming', 'Flemming'] -> Representative: Fleming
# Cluster 63: ['Fletcher', 'Valdemar', 'Vladamir', 'Vladimir', 'Voltaire', 'Waldemar'] -> Representative: Fletcher
# Cluster 180: ['Flint', 'Noland', 'Orlando', 'Roland', 'Rolando', 'Rolland', 'Rollins', 'Rowland'] -> Representative: Flint
# Cluster 197: ['Forbes'] -> Representative: Forbes
# Cluster 96: ['Forester', 'Forrester', 'Forster', 'Foster', 'Fraser'] -> Representative: Foster
# Cluster 192: ['Francesco', 'Francis', 'Francisco'] -> Representative: Francis
# Cluster 169: ['Franklin', 'Franklyn'] -> Representative: Franklin
# Cluster 94: ['Gallagher', 'Ginger', 'Gunter', 'Gunther'] -> Representative: Ginger
# Cluster 193: ['Garfinkel'] -> Representative: Garfinkel
# Cluster 2: ['Geof', 'Geoff', 'Geoffrey', 'Geoffry', 'Georg', 'George', 'Georges', 'Georgia', 'Georgie', 'Georgy', 'Giacomo', 'Giavani', 'Gideon', 'Giff', 'Giffard', 'Giffer', 'Giffie', 'Gifford', 'Giffy', 'Giorgi', 'Giorgio', 'Giovanne', 'Giovanni', 'Giuseppe', 'Jack', 'Jackie', 'Jacob', 'Jacques', 'Jaime', 'Jake', 'Jakob', 'Jamey', 'Jamie', 'Jarvis', 'Jason', 'Javier', 'Jedediah', 'Jef', 'Jeff', 'Jefferey', 'Jeffery', 'Jeffie', 'Jeffrey', 'Jeffry', 'Jefry', 'Jehu', 'Jephthah', 'Jeramie', 'Jere', 'Jereme', 'Jeremiah', 'Jeremias', 'Jeremie', 'Jeremy', 'Jerome', 'Jeromy', 'Jerri', 'Jerrie', 'Jerrome', 'Jerry', 'Jervis', 'Jerzy', 'Jess', 'Jesse', 'Jessee', 'Jessey', 'Jessie', 'Jeth', 'Jim', 'Jimbo', 'Jimmie', 'Jimmy', 'Joaquin', 'Jock', 'Joel', 'Johan', 'Johann', 'Jorge', 'Jory', 'Jose', 'Josef', 'Joseph', 'Josh', 'Joshua', 'Joshuah', 'Josiah', 'Jotham', 'Judith', 'Juergen', 'Jule', 'Julian', 'Julie', 'Julio', 'Xavier'] -> Representative: Jef
# Cluster 241: ['Giancarlo'] -> Representative: Giancarlo
# Cluster 111: ['Godfree', 'Godfrey', 'Godfry', 'Grover'] -> Representative: Godfry
# Cluster 91: ['Gonzales', 'Gonzalo', 'Kingsley', 'Kingsly'] -> Representative: Gonzalo
# Cluster 229: ['Granville'] -> Representative: Granville
# Cluster 79: ['Gustaf', 'Gustav', 'Gustave', 'Gustavo', 'Gustavus', 'Mustafa', 'Steve', 'Stevie', 'Stevy'] -> Representative: Steve
# Cluster 17: ['Hadleigh', 'Hadley', 'Hagan', 'Hagen', 'Hailey', 'Hal', 'Hale', 'Haleigh', 'Haley', 'Hall', 'Hallam', 'Hamel', 'Hamil', 'Han', 'Hanan', 'Hari', 'Harry', 'Haven', 'Hayden', 'Haydon', 'Hayes', 'Hilary', 'Hill', 'Hillary', 'Hillery', 'Hiro', 'Hogan', 'Hollis', 'Holly', 'Hugh'] -> Representative: Hal
# Cluster 181: ['Hamilton', 'Hamlen', 'Hamlet', 'Hamlin', 'Milt'] -> Representative: Milt
# Cluster 19: ['Hans', 'Heinz', 'Jabez', 'James', 'Janos', 'Janus', 'Jens', 'Jesus', 'Johannes', 'Jonas', 'Josephus', 'Juanita', 'Judas', 'Justis'] -> Representative: Hans
# Cluster 239: ['Hans-Peter'] -> Representative: Hans-Peter
# Cluster 34: ['Hanson', 'Sampson', 'Samson', 'Sanson', 'Sansone', 'Saxon'] -> Representative: Saxon
# Cluster 102: ['Haskel', 'Haskell', 'Pascal', 'Pascale', 'Pasquale', 'Skell', 'Skelly'] -> Representative: Skell
# Cluster 124: ['Hastings'] -> Representative: Hastings
# Cluster 15: ['Heath', 'Keith', 'Mathew', 'Matthew', 'Matthieu', 'Matthiew', 'Otho', 'Roth', 'Seth', 'Smith', 'Theo', 'Timothee', 'Timotheus', 'Timothy', 'Tymothy', 'Worth', 'Worthy'] -> Representative: Otho
# Cluster 213: ['Heathcliff'] -> Representative: Heathcliff
# Cluster 165: ['Hebert', 'Herbert', 'Hilbert', 'Hillard', 'Hilliard', 'Hobart', 'Hubert', 'Humbert'] -> Representative: Hebert
# Cluster 236: ['Hector', 'Victor'] -> Representative: Hector
# Cluster 168: ['Helmuth'] -> Representative: Helmuth
# Cluster 90: ['Hendrick', 'Hendrik', 'Hunter', 'Kendrick', 'Sander', 'Sandor', 'Sandro', 'Saunder', 'Saundra'] -> Representative: Hunter
# Cluster 166: ['Higgins', 'Ignace', 'Ignacio', 'Ignacius', 'Ignatius', 'Ignaz', 'Ignazio', 'Mackenzie'] -> Representative: Ignaz
# Cluster 52: ['Hudson', 'Jackson', 'Jameson', 'Judson', 'Madison'] -> Representative: Hudson
# Cluster 137: ['Humphrey'] -> Representative: Humphrey
# Cluster 121: ['Huntington'] -> Representative: Huntington
# Cluster 141: ['Ingamar', 'Ingemar', 'Ingmar'] -> Representative: Ingmar
# Cluster 164: ['Ingram'] -> Representative: Ingram
# Cluster 207: ['Jean-Christophe'] -> Representative: Jean-Christophe
# Cluster 205: ['Jean-Francois'] -> Representative: Jean-Francois
# Cluster 150: ['Jean-Lou', 'Jean-Luc', 'Jean-Paul', 'Jean-Pierre'] -> Representative: Jean-Lou
# Cluster 190: ['Jean-Marc'] -> Representative: Jean-Marc
# Cluster 185: ['Jefferson'] -> Representative: Jefferson
# Cluster 206: ['Jennings'] -> Representative: Jennings
# Cluster 125: ['John-David'] -> Representative: John-David
# Cluster 60: ['John-Patrick'] -> Representative: John-Patrick
# Cluster 224: ['Johnathan', 'Johnathon', 'Jonathan', 'Jonathon'] -> Representative: Jonathan
# Cluster 113: ['Kimball', 'Temp', 'Temple'] -> Representative: Temp
# Cluster 68: ['Kingston', 'Langston'] -> Representative: Kingston
# Cluster 119: ['Lambert'] -> Representative: Lambert
# Cluster 238: ['Lance', 'Leonidas', 'Lindsay', 'Lindsey', 'Linus'] -> Representative: Lance
# Cluster 219: ['Lancelot'] -> Representative: Lancelot
# Cluster 86: ['Lawson', 'Lazar', 'Lazare', 'Lazaro', 'Lazlo', 'Lesley', 'Leslie', 'Llewellyn', 'Logan', 'Lovell', 'Lucian', 'Luciano', 'Lucien', 'Nealson', 'Nelsen', 'Nelson', 'Nilson', 'Wilson'] -> Representative: Lazar
# Cluster 198: ['Lazarus'] -> Representative: Lazarus
# Cluster 47: ['Lefty', 'Lockwood', 'Nikita'] -> Representative: Lefty
# Cluster 89: ['Lenard', 'Leonard', 'Leonardo', 'Leonerd', 'Leonhard', 'Leonid', 'Lind', 'Lindy', 'Maynard', 'Maynord', 'Menard', 'Mendie', 'Monte', 'Monty'] -> Representative: Lind
# Cluster 131: ['Lincoln'] -> Representative: Lincoln
# Cluster 221: ['Ludvig'] -> Representative: Ludvig
# Cluster 73: ['Magnum', 'Magnus', 'Munmro'] -> Representative: Magnum
# Cluster 158: ['Mahesh', 'Mohan'] -> Representative: Mohan
# Cluster 215: ['Malcolm'] -> Representative: Malcolm
# Cluster 32: ['Marcel', 'Marcello', 'Marcellus', 'Marcelo', 'Maxim', 'Maxwell'] -> Representative: Maxim
# Cluster 54: ['Marmaduke', 'Meredeth', 'Meredith', 'Montague', 'Mordecai', 'Murdoch', 'Murdock'] -> Representative: Murdoch
# Cluster 201: ['Maxfield'] -> Representative: Maxfield
# Cluster 105: ['Maximilian', 'Maximilien'] -> Representative: Maximilian
# Cluster 160: ['Millicent'] -> Representative: Millicent
# Cluster 220: ['Mohamad', 'Mohamed', 'Mohammad', 'Mohammed', 'Muhammad'] -> Representative: Mohamad
# Cluster 222: ['Montgomery'] -> Representative: Montgomery
# Cluster 144: ['Mortimer'] -> Representative: Mortimer
# Cluster 148: ['Napoleon', 'Zebulen', 'Zebulon'] -> Representative: Zebulen
# Cluster 188: ['Nathanael', 'Nathanial', 'Nathaniel', 'Nathanil'] -> Representative: Nathanil
# Cluster 120: ['Northrop', 'Northrup'] -> Representative: Northrop
# Cluster 161: ['Octavius'] -> Representative: Octavius
# Cluster 174: ['Osborn', 'Osborne', 'Osbourn', 'Osbourne', 'Wilburn'] -> Representative: Osborn
# Cluster 98: ['Osgood', 'Oswald'] -> Representative: Osgood
# Cluster 237: ['Parsifal', 'Perceval', 'Percival'] -> Representative: Parsifal
# Cluster 142: ['Pembroke'] -> Representative: Pembroke
# Cluster 194: ['Ransell', 'Ransom'] -> Representative: Ransom
# Cluster 204: ['Remington'] -> Representative: Remington
# Cluster 106: ['Rogers', 'Scarface', 'Socrates', 'Zacharias'] -> Representative: Rogers
# Cluster 110: ['Roosevelt'] -> Representative: Roosevelt
# Cluster 147: ['Rutherford'] -> Representative: Rutherford
# Cluster 149: ['Salem', 'Salim', 'Salman', 'Salmon', 'Salomo', 'Salomon', 'Salomone', 'Shalom', 'Shlomo', 'Sholom', 'Slim', 'Sloan', 'Sloane', 'Solomon', 'Stillman', 'Stillmann', 'Zalman'] -> Representative: Slim
# Cluster 29: ['Salvador', 'Salvatore', 'Salvidor', 'Silvester', 'Sylvester'] -> Representative: Salvador
# Cluster 7: ['Sandy', 'Scot', 'Scott', 'Scotti', 'Scottie', 'Scotty', 'Selby', 'Selig', 'Skip', 'Skipp', 'Skipper', 'Skippie', 'Skippy', 'Slade', 'Spike', 'Spud', 'Zebadiah', 'Zebedee', 'Zelig'] -> Representative: Scot
# Cluster 99: ['Sarge', 'Serge', 'Sergei', 'Sergio', 'Verge', 'Vergil', 'Virge', 'Virgie', 'Virgil', 'Virgilio'] -> Representative: Sarge
# Cluster 130: ['Sargent', 'Sergeant', 'Sergent'] -> Representative: Sargent
# Cluster 183: ['Schuyler', 'Sinclair', 'Sinclare', 'Skylar', 'Skyler'] -> Representative: Skylar
# Cluster 199: ['Sebastian', 'Sebastiano', 'Sebastien'] -> Representative: Sebastian
# Cluster 184: ['Sheffield', 'Shepard', 'Shepherd', 'Sheppard', 'Shepperd'] -> Representative: Shepard
# Cluster 230: ['Sigmund'] -> Representative: Sigmund
# Cluster 171: ['Simmonds', 'Spence', 'Spense', 'Sumner', 'Ximenes', 'Ximenez', 'Xymenes'] -> Representative: Spence
# Cluster 232: ['Skipton'] -> Representative: Skipton
# Cluster 153: ['Somerset'] -> Representative: Somerset
# Cluster 218: ['Sparky', 'Spiros'] -> Representative: Sparky
# Cluster 227: ['Srinivas'] -> Representative: Srinivas
# Cluster 50: ['Standford', 'Stanfield', 'Stanford'] -> Representative: Stanford
# Cluster 175: ['Stanton'] -> Representative: Stanton
# Cluster 109: ['Stavros', 'Stephanus'] -> Representative: Stavros
# Cluster 214: ['Sterling', 'Stirling'] -> Representative: Sterling
# Cluster 212: ['Sturgis'] -> Representative: Sturgis
# Cluster 210: ['Sutherland'] -> Representative: Sutherland
# Cluster 231: ['Templeton'] -> Representative: Templeton
# Cluster 216: ['Theophyllus'] -> Representative: Theophyllus
# Cluster 107: ['Thorvald'] -> Representative: Thorvald
# Cluster 195: ['Townsend', 'Vincent', 'Vincents'] -> Representative: Vincent
# Cluster 62: ['Traver', 'Travers', 'Trevar', 'Trever', 'Trevor', 'Turner'] -> Representative: Traver
# Cluster 186: ['Vaclav'] -> Representative: Vaclav
# Cluster 139: ['Vasilis'] -> Representative: Vasilis
# Cluster 138: ['Vilhelm', 'Wilhelm'] -> Representative: Vilhelm
# Cluster 132: ['Washington'] -> Representative: Washington
# Cluster 157: ['Westbrook', 'Westbrooke'] -> Representative: Westbrook
# Cluster 103: ['Winthrop'] -> Representative: Winthrop
# Cluster 233: ['Wojciech'] -> Representative: Wojciech
# Cluster 177: ['Wolfgang'] -> Representative: Wolfgang
# Cluster 203: ['Worthington'] -> Representative: Worthington
# Cluster 72: ['Xerxes'] -> Representative: Xerxes
